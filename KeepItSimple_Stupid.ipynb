# %% [markdown]
# <a href="https://colab.research.google.com/github/epsilon-deltta/sl-for-dl/blob/master/dl-torch/baseline_fashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if you are in colab env
# !git init
# !git pull https://github.com/epsilon-deltta/ssd_simple.git

# %% [markdown]
# ### Import detection

# %%
from detect import detect 
from detect import model
# Out:
# Loaded checkpoint from epoch 232.
# /home/yp/anaconda3/envs/p36/lib/python3.6/site-packages/torch/serialization.py:656: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/yp/anaconda3/envs/p36/lib/python3.6/site-packages/torch/serialization.py:656: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %% [markdown]
# ### Image test

# %%
# Test built-in dataset
from PIL import Image
img_path = './img/000022.jpg'
original_image = Image.open(img_path, mode='r')
original_image = original_image.convert('RGB')
anno_img = detect(model,original_image)
from IPython.display import display
display(anno_img)
# Out:
# /home/yp/workspace/ssd_simple/model.py:501: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /opt/conda/conda-bld/pytorch_1616554789074/work/aten/src/ATen/native/IndexingUtils.h:30.)
#   image_boxes.append(class_decoded_locs[1 - suppress])
# /home/yp/workspace/ssd_simple/model.py:503: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /opt/conda/conda-bld/pytorch_1616554789074/work/aten/src/ATen/native/IndexingUtils.h:30.)
#   image_scores.append(class_scores[1 - suppress])
# <PIL.Image.Image image mode=RGB size=500x332 at 0x7F6CF4182518>

# %%
# Test internet image
from  PIL import Image
import requests as rq
import io
from PIL import  ImageDraw
from IPython.display import display


# imgurl ='https://t3.daumcdn.net/thumb/R720x0/?fname=http://t1.daumcdn.net/brunch/service/user/1e0Z/image/7ulVcf_Wh5VicfYz2sVq3v_z37Y.jpg' 
imgurl = 'https://static01.nyt.com/images/2017/11/03/nyregion/00pedxing01/00pedxing01-superJumbo.jpg' #2048 x 1365
imgurl = 'https://mybayutcdn.bayut.com/mybayut/wp-content/uploads/Pesdestrain-safety-in-Dubai-23rd-June.jpg' #1444x625
imgurl = 'http://imagescdn.gettyimagesbank.com/500/20/789/660/0/1288939997.jpg' # 416x416 animation img
imgurl = 'https://thenewswheel.com/wp-content/uploads/2018/04/pexels-photo-109919-760x428.jpeg' #760x428
kokobyte = rq.get(imgurl).content

koko = Image.open(io.BytesIO(kokobyte))
anno_img = detect(model,koko)
display(anno_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x428 at 0x7F6CF0491CC0>

# %% [markdown]
# ### Video test

# %%
- show 
- store

# %% [markdown]
# ### comparison
